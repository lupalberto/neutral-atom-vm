# %% [markdown]
# ### Stim stabilizer notebook
#
# This notebook reuses the `stabilizer` device alias to run a Stim-backed kernel that measures two stabilizers and a final readout on the new 2D grid profile.

# %% [markdown]
# #### Step 1 – inspect the stabilizer profile

# %%
from neutral_atom_vm import ProfileConfigurator

configurator = ProfileConfigurator(default_device='stabilizer', default_profile='ideal_square_grid')
configurator.render()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Device', index=1, layout=Layout(width='280px'), options=('…

# %% [markdown]
# #### Step 2 – load the stabilizer kernel

# %%
from bloqade import squin


@squin.kernel
def stabilizer_syndrome_cycle():
    # Four data qubits plus two ancilla qubits used for X- and Z-parity checks.
    data = squin.qalloc(4)
    anc_x = squin.qalloc(1)
    anc_z = squin.qalloc(1)

    # Prepare data register in a pattern mixing |+> and |1>, forcing Stim to
    # track both X- and Z-type correlations.
    for idx in (0, 2):
        squin.h(data[idx])
    squin.x(data[3])

    # Build two short Bell pairs to provide entanglement structure.
    squin.cx(data[0], data[1])
    squin.cx(data[2], data[3])

    # X stabilizer check spanning qubits 0 and 1 via ancilla anc_x.
    squin.h(data[0])
    squin.h(data[1])
    squin.cx(data[0], anc_x[0])
    squin.cx(data[1], anc_x[0])
    squin.h(data[0])
    squin.h(data[1])
    squin.measure(anc_x)

    # Z stabilizer check across qubits 1 and 2 (adjacent under the 2D grid).
    squin.cx(data[1], anc_z[0])
    squin.cx(data[2], anc_z[0])
    squin.measure(anc_z)

    # Final readout of all data qubits to correlate with the stabilizer outcomes.
    squin.measure(data)

# %% [markdown]
# #### Step 3 – build a stabilizer device

# %%
from neutral_atom_vm import build_device_from_config

payload = configurator.profile_payload
dev = build_device_from_config(
    payload["device_id"],
    profile=payload["profile"],
    config=payload["config"],
)

# %% [markdown]
# #### Step 4 – submit and inspect the stabilizer job

# %%
job = dev.submit(stabilizer_syndrome_cycle, shots=256)
result = job.result()
result
# Out:
# {'job_id': 'python-client',
#  'status': 'completed',
#  'elapsed_time': 0.00077038,
#  'measurements': [{'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [0, 0, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [1]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 0, 1]},
#   {'targets': [4], 'bits': [0]},
#   {'targets': [5], 'bits': [0]},
#   {'targets': [0, 1, 2, 3], 'bits': [1, 1, 1, 0]}],
#  'message': '',
#  'log_time_units': 'us',
#  'logs': [{'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[0] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[2] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate X targets=[3] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[0,1] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[2,3] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[0] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[1] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[0,4] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[1,4] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[0] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate H targets=[1] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'Measure targets=[4] duration_us=50'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[1,5] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Timeline',
#    'message': 'ApplyGate CX targets=[2,5] param=0 duration_us=0'},
#   {'shot': 0,
#    'time': 50.0,
#    'category': 'Timeline',
#    'message': 'Measure targets=[5] duration_us=50'},
#   {'shot': 0,
#    'time': 100.0,
#    'category': 'Timeline',
#    'message': 'Measure targets=[0,1,2,3] duration_us=50'}],
#  'timeline_units': 'us',
#  'timeline': [{'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[0] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[2] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'X targets=[3] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[0,1] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[2,3] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[0] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[1] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[0,4] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[1,4] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[0] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'H targets=[1] param=0'},
#   {'start_time': 0.0,
#    'duration': 50.0,
#    'op': 'Measure',
#    'detail': 'targets=[4]'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[1,5] param=0'},
#   {'start_time': 0.0,
#    'duration': 0.0,
#    'op': 'ApplyGate',
#    'detail': 'CX targets=[2,5] param=0'},
#   {'start_time': 50.0,
#    'duration': 50.0,
#    'op': 'Measure',
#    'detail': 'targets=[5]'},
#   {'start_time': 100.0,
#    'duration': 50.0,
#    'op': 'Measure',
#    'detail': 'targets=[0,1,2,3]'}]}

# %% [markdown]
# #### Step 5 – summarize the outcomes

# %%
from collections import Counter, defaultdict

timeline = result.get("timeline", [])
print(f"Collected {len(timeline)} timeline entries (units={result.get('timeline_units')})")
for entry in timeline[:5]:
    print(entry)

counts_by_targets = defaultdict(Counter)
for record in result.get("measurements", []):
    targets = tuple(record.get("targets", []))
    if not targets:
        continue
    bits = "".join(str(int(b)) for b in record.get("bits", []))
    counts_by_targets[targets][bits] += 1

for targets, counter in sorted(counts_by_targets.items(), key=lambda item: item[0]):
    total = sum(counter.values())
    print(f"Targets {list(targets)}: {total} samples")
    for bitstring, count in counter.most_common():
        print(f"  {bitstring}: {count}")
# Out:
# Collected 16 timeline entries (units=us)
# {'start_time': 0.0, 'duration': 0.0, 'op': 'ApplyGate', 'detail': 'H targets=[0] param=0'}
# {'start_time': 0.0, 'duration': 0.0, 'op': 'ApplyGate', 'detail': 'H targets=[2] param=0'}
# {'start_time': 0.0, 'duration': 0.0, 'op': 'ApplyGate', 'detail': 'X targets=[3] param=0'}
# {'start_time': 0.0, 'duration': 0.0, 'op': 'ApplyGate', 'detail': 'CX targets=[0,1] param=0'}
# {'start_time': 0.0, 'duration': 0.0, 'op': 'ApplyGate', 'detail': 'CX targets=[2,3] param=0'}
# Targets [0, 1, 2, 3]: 256 samples
#   1110: 71
#   1101: 65
#   0001: 64
#   0010: 56
# Targets [4]: 256 samples
#   0: 256
# Targets [5]: 256 samples
#   0: 135
#   1: 121
