# %% [markdown]
# ### Remote notebook
#
# Exercise the Dockerized service path: serialize a `JobRequest`, and POST it to the running VM service, demonstrating the remote submission path mentioned under the UX operator journey.

# %%
from neutral_atom_vm import ProfileConfigurator, connect_device, build_device_from_config

# %% [markdown]
# #### Step 1 – define a small Bell-pair kernel
#
# Define a minimal Squin kernel (`bell_pair`) that entangles two qubits and measures them. We will run this kernel both locally and via the remote VM service.

# %%
from bloqade import squin

@squin.kernel
def bell_pair():
    q = squin.qalloc(2)

    # Put the first site into superposition
    squin.h(q[0])
    squin.cx(q[0], q[1])

    squin.measure(q)

# %% [markdown]
# #### Step 2 – connect to the remote service
#
# Use `connect_device` with a `service_url` to point the SDK at a running Dockerized VM service. From the notebook’s perspective this still looks like a normal device handle; the difference is that jobs are POSTed over HTTP.

# %%
dev = connect_device('local-cpu', profile="ideal_small_array", service_url='http://localhost:8080/job')

# %%
job = dev.submit(bell_pair, shots=1000)
result = job.result()
result
# Out:
# {'job_id': 'job-13',
#  'status': 'completed',
#  'elapsed_time': 0.009744144,
#  'measurements': [{'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]}],
#  'message': '',
#  'logs': [{'shot': 0,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 14,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 14,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 14,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 14,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 15,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 15,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 15,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 15,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 16,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 16,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 16,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 16,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 17,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 17,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 17,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 17,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 18,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 18,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 18,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 18,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 19,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 19,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 19,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 19,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 20,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 20,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 20,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 20,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 21,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 21,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 21,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 21,
#    'time': 0.0,
# ...
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 211,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 211,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 212,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 212,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 212,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 212,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 213,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 213,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 213,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 213,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 214,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 214,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 214,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 214,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 215,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 215,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 215,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 215,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 216,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 216,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 216,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 216,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 217,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 217,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 217,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 217,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 218,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 218,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 218,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 218,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 219,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 219,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 219,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 219,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 220,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 220,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 220,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 220,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 221,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 221,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 221,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 221,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 222,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 222,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 222,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 222,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 223,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 223,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 223,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 223,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 224,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 224,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 224,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 224,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 225,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 225,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 225,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 225,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 226,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 226,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 226,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 226,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 227,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 227,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 227,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 227,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 228,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 228,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 228,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 228,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 229,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 229,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 229,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 229,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 230,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 230,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 230,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 230,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 231,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 231,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 231,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 231,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 232,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 232,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 232,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 232,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 233,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 233,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 233,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 233,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 234,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 234,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 234,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 234,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 235,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 235,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 235,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 235,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 236,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 236,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 236,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 236,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 237,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 237,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 237,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 237,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 238,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 238,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 238,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 238,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 239,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 239,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 239,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 239,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 240,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 240,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 240,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 240,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 241,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 241,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 241,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 241,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 242,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 242,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 242,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 242,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 243,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 243,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 243,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 243,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 244,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 244,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 244,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 244,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 245,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 245,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 245,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 245,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 246,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 246,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 246,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 246,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 247,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 247,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 247,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 247,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 248,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 248,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 248,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 248,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 249,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 249,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 249,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 249,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   ...]}

# %% [markdown]
# #### Step 3 – explore profiles on the service
#
# Instantiate a `ProfileConfigurator` that talks to the same service URL. This lets you discover and tweak device profiles exposed by the remote VM, not just local presets. The UI is generated dynamically based on the devices and profiles exposed by the remote service.

# %%
configurator = ProfileConfigurator(service_url="http://localhost:8080", default_device='local-cpu', default_profile='lossy_block')
configurator.render()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Device', layout=Layout(width='280px'), options=('local-cpu…

# %%
  payload = configurator.profile_payload
  dev = build_device_from_config(
      payload["device_id"],
      profile=payload["profile"],
      config=payload["config"],
      service_url="http://localhost:8080/job",
  )

# %% [markdown]
# #### Step 4 – run with a configured remote profile
#
# Build a device from the configurator payload and submit the same `bell_pair` kernel again, this time using the remote profile. Comparing these runs shows how the service path mirrors the local SDK journey.

# %%
job = dev.submit(bell_pair, shots=1000)
result = job.result()
result
# Out:
# {'job_id': 'job-16',
#  'status': 'completed',
#  'elapsed_time': 0.010002626,
#  'measurements': [{'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [-1, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [0, -1]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [1, 1]},
#   {'targets': [0, 1], 'bits': [0, 0]},
#   {'targets': [0, 1], 'bits': [0, -1]}],
#  'message': '',
#  'logs': [{'shot': 0,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 0,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,-1]'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 1,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 2,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,-1]'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 3,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 4,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 5,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 6,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 7,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 8,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 9,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,-1]'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 10,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 11,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 12,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 13,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 13,
#    'time': 0.0,
# ...
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 141,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 142,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 143,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,0]'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 144,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 145,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,-1]'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 146,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 147,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,-1]'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 148,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,-1]'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 149,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,1]'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 150,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 151,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 152,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 153,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 154,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,0]'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 155,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,0]'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 156,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 157,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 158,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 159,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 160,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 161,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 162,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 163,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[0,0]'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 164,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[-1,1]'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'CX targets=[0,1] param=0'},
#   {'shot': 165,
#    'time': 0.0,
#    'category': 'Measure',
#    'message': 'Measure targets=[0,1] bits=[1,1]'},
#   {'shot': 166,
#    'time': 0.0,
#    'category': 'AllocArray',
#    'message': 'AllocArray n_qubits=2'},
#   {'shot': 166,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Single-qubit noise applied to target=0'},
#   {'shot': 166,
#    'time': 0.0,
#    'category': 'ApplyGate',
#    'message': 'H targets=[0] param=0'},
#   {'shot': 166,
#    'time': 0.0,
#    'category': 'Noise',
#    'message': 'Two-qubit noise applied to targets=[0,1]'},
#   ...]}
